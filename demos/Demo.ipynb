# %%
import Evaluate

# %%
repository_name, limit = Evaluate.main_1()
# Out:
# Which data repository do you want to use?
# 1. ArrayExpress
# 2. Gene Expression Omnibus
# 3. GWAS Catalog
# 4. ENCODE
# 5. GENOMIC DATA COMMONS
# 6. ICGC

# %%
metadata, repository_choice, url, request_status = Evaluate.initialize(repository_name, limit)
metadata
# Out:
# Experiment IDs: ['E-MTAB-3628', 'E-MTAB-5729', 'E-MTAB-2312']
# [{'accno': 'E-MTAB-3628',
#   'attributes': [{'name': 'Title',
#     'value': 'Exogenous BRCT-GST of PARP1 bind to wild-type p53. p53 was overexpressed  after UV treatment  in U2OS.'},
#    {'name': 'ReleaseDate', 'value': '2024-03-02'},
#    {'name': 'RootPath', 'value': 'E-MTAB-3628'},
#    {'name': 'AttachTo', 'value': 'ArrayExpress'}],
#   'section': {'accno': 's-E-MTAB-3628',
#    'type': 'Study',
#    'attributes': [{'name': 'Title',
#      'value': 'MicroRNA profiling by array of U2OS cells overexpressing the BRCT domain of PARP1 after UV radiation'},
#     {'name': 'Study type',
#      'value': 'microRNA profiling by array',
#      'valqual': [{'name': 'Ontology', 'value': 'EFO'},
#       {'name': 'TermId', 'value': 'EFO_0000753'}]},
#     {'name': 'Organism', 'value': 'Homo sapiens'},
#     {'name': 'Description',
# ...

# %%
Evaluate.assess(metadata, [], repository_choice, url, request_status)
# Out:
#   Principle                           Description  Score           Explanation
# 0        F1  Findability: DOI presence in webpage      1  DOI found in webpage
#   Principle                              Description  Score  \
# 0        F2  Findability: Keyword search in metadata      1
#
#                            Explanation
# 0  Keywords found with percentage: 100
# #ZEROS: 1
# #ONES: 2
#   Principle                         Description     Score  \
# 0        F3  Findability: Check for identifiers  0.666667
#
#                                          Explanation
# 0  Identifiers found in 66.66666666666666% of ent...
# #ZEROS: 0
# #ONES: 3
#   Principle                               Description  Score  \
# 0        F4  Findability: Presence in Google Datasets    1.0
#
#                                        Explanation
# 0  Datasets found in Google Dataset Search: 100.0%
#   Principle                    Description  Score         Explanation
# ...
