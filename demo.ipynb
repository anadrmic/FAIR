# %%
from repositories import retrieve_metadata
from assess import assess
# Out:
# /Users/anadrmic/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
keywords = ["parkinson", "homo sapiens", "frontal lobe"]
repository_choice = "1"

# %%
metadata_list, request_status, url = retrieve_metadata(repository_choice, keywords)
# Out:
# Fetching ArrayExpress metadata...
# Fetching metadata with keywords: ['parkinson', 'homo sapiens', 'frontal lobe']
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/search?query=parkinson+AND+homo+sapiens+AND+frontal+lobe&pageSize=500
# Total Study IDs retrieved: 13
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/studies/E-MTAB-1194
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/studies/E-GEOD-28894
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/studies/S-BIAD1133
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/studies/E-GEOD-26927
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/studies/E-GEOD-8397
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/studies/E-GEOD-72962
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/studies/E-GEOD-15826
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/studies/E-GEOD-32970
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/studies/S-SCDT-EMM-2021-14745
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/studies/E-GEOD-7307
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/studies/E-MTAB-2325
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/studies/E-TABM-185
# API Call: https://www.ebi.ac.uk/biostudies/api/v1/studies/E-MTAB-3732
#
# The dataset is fetched!

# %%
scores = assess(metadata_list, keywords, repository_choice, url, request_status)
# Out:
# ______________________________________________________________________________________________________________
# Principle: F1
# Description: Findability: DOI presence in webpage
# Score: 1
# Explanation: The data source has a valid DOI associated with it available at re3data: ['10.25504/FAIRsharing.6k0kwd', '10.17616/R3302G', '10.17616/R3D'].
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Principle: F2
# Description: Findability: Keyword search in metadata
# Score: 1.0
# Explanation: 100.00% of entities have all required fields (13 out of 13).
# 0.00% of entities are missing all required fields (0 out of 13).
#
# Breakdown of missing fields:
# 0 entities are missing 'value' field.
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Principle: F3
# Description: Findability: Check for identifiers
# Score: 1.0
# Explanation: 100.00% of entities have an ID field (13 out of 13).
# 0.00% of entities are missing the ID field (0 out of 13).
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Principle: F4
# Description: Findability: Presence in Google Datasets
# Score: 0.85
# Explanation: Datasets found in Google Dataset Search: 85.0%
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Principle: A1
# Description: Accessibility: Request status
# Score: 1
# Explanation: Successful request: API request returned the status 200.
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Principle: A1
# Description: Accessibility: Request status
# Score: 1
# Explanation: Successful request: API request returned the status 200.
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Principle: A1.1
# Description: Accessibility: Check after A1
# Score: 1
# Explanation: Follow-up check successful: API request returned the status 200.
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Principle: A1
# Description: Accessibility: Request status
# Score: 1
# Explanation: Successful request: API request returned the status 200.
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Principle: A1.1
# Description: Accessibility: Check after A1
# Score: 1
# Explanation: Follow-up check successful: API request returned the status 200.
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Principle: A1.2
# Description: Accessibility: Another check after A1
# Score: 1
# Explanation: Additional check successful: API request returned the status 200.
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Principle: A2
# Description: Accessibility: Repository name check
# Score: 1
# Explanation: Repository is known to be accessible: the repository is available on re3data.
# ______________________________________________________________________________________________________________
# (Meta)data is in format: json
# (Meta)data is in format: json
# (Meta)data is in format: json
# (Meta)data is in format: json
# (Meta)data is in format: json
# (Meta)data is in format: json
# (Meta)data is in format: json
# (Meta)data is in format: json
# (Meta)data is in format: json
# (Meta)data is in format: json
# (Meta)data is in format: json
# (Meta)data is in format: json
# (Meta)data is in format: json
# ______________________________________________________________________________________________________________
# Principle: I1
# Description: Interoperability: Format check
# Score: 1.0
# Explanation: Format is json.
# ______________________________________________________________________________________________________________
# ['EFO', 'EFO_0002768']
# ['EFO', 'EFO_0002768']
# []
# ['EFO', 'EFO_0002768']
# ['EFO', 'EFO_0002768']
# ['EFO', 'EFO_0003737']
# ['EFO', 'EFO_0000749', 'EFO', 'EFO_0002767']
# ['EFO', 'EFO_0002692']
# []
# ['EFO', 'EFO_0002768']
# ['EFO', 'EFO_0002768']
# ['EFO', 'EFO_0002768']
# ['EFO', 'EFO_0002768']
# ______________________________________________________________________________________________________________
# Principle: I2
# Description: Interoperability: Ontology check
# Score: 100.0
# Explanation: Ontology is used and valid in 100.00% of entities.
# ______________________________________________________________________________________________________________
# Field: refs, Value: None (Missing or empty)
# Field: refs, Value: None (Missing or empty)
# Field: refs, Value: None (Missing or empty)
# Field: refs, Value: None (Missing or empty)
# Field: refs, Value: None (Missing or empty)
# Field: refs, Value: None (Missing or empty)
# Field: refs, Value: None (Missing or empty)
# Field: refs, Value: None (Missing or empty)
# Field: refs, Value: None (Missing or empty)
# Field: refs, Value: None (Missing or empty)
# Field: refs, Value: None (Missing or empty)
# Field: refs, Value: None (Missing or empty)
# Field: refs, Value: None (Missing or empty)
# ______________________________________________________________________________________________________________
# Principle: I3
# Description: Interoperability: Metadata include qualified references to other (meta)data
# Score: 0.0
# Explanation: 0.00% of entities have a reference to other metadata.
# ______________________________________________________________________________________________________________
# Field: supp, Value: None (Missing or empty)
# Field: supp, Value: None (Missing or empty)
# Field: supp, Value: None (Missing or empty)
# Field: supp, Value: None (Missing or empty)
# Field: supp, Value: None (Missing or empty)
# Field: supp, Value: None (Missing or empty)
# Field: supp, Value: None (Missing or empty)
# Field: supp, Value: None (Missing or empty)
# Field: supp, Value: None (Missing or empty)
# Field: supp, Value: None (Missing or empty)
# Field: supp, Value: None (Missing or empty)
# Field: supp, Value: None (Missing or empty)
# Field: supp, Value: None (Missing or empty)
# ______________________________________________________________________________________________________________
# Principle: R1
# Description: Reusability: Metadata completeness
# Score: 0.0
# Explanation: Metadata is incomplete: it does not include the type of object nor the metadata specify the content of the data technical properties of its data file and format.
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Principle: R1.2
# Description: Reusability: Use of community standards
# Score: 1
# Explanation: All community standards fields present
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Principle: R1.2
# Description: Reusability: Provenance standards metadata completeness
# Score: 0.92
# Explanation: No provenance metadata present: no author, email or title specified.
# ______________________________________________________________________________________________________________
# ╒════════════╤═════════╕
# │ Metric     │   Score │
# ╞════════════╪═════════╡
# │ F1 score   │    1    │
# ├────────────┼─────────┤
# │ F2 score   │    1    │
# ├────────────┼─────────┤
# │ F3 score   │    1    │
# ├────────────┼─────────┤
# │ F4 score   │    0.85 │
# ├────────────┼─────────┤
# │ A1 score   │    1    │
# ├────────────┼─────────┤
# │ A1.1 score │    1    │
# ├────────────┼─────────┤
# │ A1.2 score │    1    │
# ├────────────┼─────────┤
# │ A2 score   │    1    │
# ├────────────┼─────────┤
# │ I1 score   │    1    │
# ├────────────┼─────────┤
# │ I2 score   │    1    │
# ├────────────┼─────────┤
# │ I3 score   │    0    │
# ├────────────┼─────────┤
# │ R1 score   │    0    │
# ├────────────┼─────────┤
# │ R1.1 score │    1    │
# ├────────────┼─────────┤
# │ R1.2 score │    0.92 │
# ╘════════════╧═════════╛
